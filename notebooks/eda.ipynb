# %%
import pandas as pd
import seaborn as sns

lyrics_df = pd.read_pickle('saved_song_lyrics.pkl')
spotify_df = pd.read_pickle('starred_songs.pkl')

# %%
lyrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 4 columns):
# artist    180 non-null object
# song      180 non-null object
# lyrics    180 non-null object
# year      135 non-null object
# dtypes: object(4)
# memory usage: 5.7+ KB

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 25 columns):
# time_added                313 non-null object
# release_date              313 non-null object
# release_date_precision    313 non-null object
# artist_name               313 non-null object
# artist_id                 313 non-null object
# song_id                   313 non-null object
# song_length_ms            313 non-null int64
# song_name                 313 non-null object
# popularity                313 non-null int64
# loudness                  313 non-null float64
# tempo                     313 non-null float64
# tempo_confidence          313 non-null float64
# time_signature            313 non-null int64
# time_sig_conf             313 non-null float64
# key                       313 non-null int64
# key_confidence            313 non-null float64
# mode                      313 non-null int64
# mode_confidence           313 non-null float64
# ...

# %%
spotify_df['release_date'] = pd.to_datetime(spotify_df['release_date'])

# %%
sns.catplot('key', 'popularity', data=spotify_df, kind='box')

# %%
sns.relplot('valence', 'popularity', data=spotify_df)

# %%
spotify_df.describe()
# Out:
#        song_length_ms  popularity    loudness       tempo  tempo_confidence  \
# count      309.000000  309.000000  309.000000  309.000000        309.000000
# mean    250068.611650   32.084142   -9.373110  118.445858          0.459851
# std      83109.343613   18.821945    3.422727   28.991190          0.286607
# min      85400.000000    0.000000  -24.326000   59.726000          0.000000
# 25%     196754.000000   19.000000  -11.500000   95.013000          0.208000
# 50%     232530.000000   34.000000   -8.946000  115.009000          0.428000
# 75%     290226.000000   46.000000   -6.944000  135.122000          0.731000
# max     624683.000000   70.000000   -2.355000  202.015000          1.000000
#
#        time_signature  time_sig_conf         key  key_confidence        mode  \
# count      309.000000     309.000000  309.000000      309.000000  309.000000
# mean         3.909385       0.911518    5.177994        0.500405    0.669903
# ...

# %%
lyrics_df.head()
# Out:
#             artist                              song  \
# 0    Timber Timbre        Lay Down in the Tall Grass
# 1      Nina Simone  I Want a Little Sugar in My Bowl
# 2        Club Kuru                 The Memory Junkie
# 3    Richard Swift                             HZLWD
# 4  Adrianne Lenker                           ​symbol
#
#                                               lyrics        year
# 0  [Verse 1]\nLay down in the tall grass\nIn a fl...  2009-01-13
# 1  I want a little sugar in my bowl\nI want a lit...        None
# 2  She's a doll in ever after\nShe's a ghost insi...  2018-01-01
# 3                                     (Instrumental)  2018-09-21
# 4  [Verse]\nFly make flea, make haste, make waste...  2018-09-12

# %%
import numpy as np
i = np.random.randint(0, lyrics_df.shape[0])
print(lyrics_df.loc[i, 'song'], lyrics_df.loc[i, 'artist'], sep=' by ')
print('')
print(lyrics_df.loc[i, 'lyrics'])
# Out:
# Strange Boy by El Michels Affair
#
# Strange boy you make no sense
# And when you talk the room gets tense
# Strange boy, you drink your fill
# You only like me cause I'm new
#
# I like you anyway
# I like you anyway
# You're gonna be famous one day
# You'll see
#
# You're so strange boy, yeah
# You're so strange boy, yeah
# You're so strange boy, yeah
# You're so strange
#
# Strange boy i'll talk you up
# I'll drink the kool aid from your cup
# Strange boy you made your bed
# Now go to sleep and rest your head
#
# I like you anyway
# I like you anyway
# You're gonna be famous one day
# You'll see
#
# You're so strange boy, yeah
# You're so strange boy, yeah
# You're so strange boy, yeah
# You're so strange
#
# You're so strange, boy
# You're so strange
